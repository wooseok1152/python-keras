# %%
# 순방향 LSTM 모델링

from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence

max_words = 10000
maxlen_for_padding = 500

(train_x, train_y), (test_x, test_y) = imdb.load_data(num_words=max_words)

train_x = sequence.pad_sequences(train_x, maxlen=maxlen_for_padding)
test_x = sequence.pad_sequences(test_x, maxlen=maxlen_for_padding)

model = Sequential()
model.add(Embedding(max_words, 32, input_length = maxlen_for_padding))
model.add(LSTM(32))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer="rmsprop", loss = "binary_crossentropy", metrics=["acc"])

history = model.fit(train_x, train_y, batch_size = 128, epochs = 10, validation_split = 0.2)
model.summary()
# Out:
# Epoch 1/10
# 157/157 [==============================] - 40s 256ms/step - loss: 0.5213 - acc: 0.7589 - val_loss: 0.3935 - val_acc: 0.8384
# Epoch 2/10
# 157/157 [==============================] - 41s 259ms/step - loss: 0.3097 - acc: 0.8767 - val_loss: 0.3137 - val_acc: 0.8704
# Epoch 3/10
# 157/157 [==============================] - 40s 256ms/step - loss: 0.2472 - acc: 0.9067 - val_loss: 0.3004 - val_acc: 0.8738
# Epoch 4/10
# 157/157 [==============================] - 40s 254ms/step - loss: 0.2071 - acc: 0.9243 - val_loss: 0.2929 - val_acc: 0.8892
# Epoch 5/10
# 157/157 [==============================] - 39s 250ms/step - loss: 0.1810 - acc: 0.9333 - val_loss: 0.2991 - val_acc: 0.8918
# Epoch 6/10
# 157/157 [==============================] - 39s 249ms/step - loss: 0.1604 - acc: 0.9426 - val_loss: 0.3194 - val_acc: 0.8632
# Epoch 7/10
# 157/157 [==============================] - 43s 272ms/step - loss: 0.1451 - acc: 0.9481 - val_loss: 0.4182 - val_acc: 0.8668
# Epoch 8/10
# 157/157 [==============================] - 43s 276ms/step - loss: 0.1343 - acc: 0.9527 - val_loss: 0.3587 - val_acc: 0.8802
# Epoch 9/10
# 157/157 [==============================] - 40s 257ms/step - loss: 0.1242 - acc: 0.9568 - val_loss: 0.5396 - val_acc: 0.8640
# Epoch 10/10
# 157/157 [==============================] - 40s 256ms/step - loss: 0.1144 - acc: 0.9612 - val_loss: 0.3389 - val_acc: 0.8790
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 500, 32)           320000
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8320
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 328,353
# Trainable params: 328,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 위 모델링에 대한 결과
# %matplotlib inline

acc = history.history["acc"]
loss = history.history["loss"]
val_acc = history.history["val_acc"]
val_loss = history.history["val_loss"]

epochs = list(range(1, len(acc) + 1))

plt.plot(epochs, acc, "bo", label = "Training acc")
plt.plot(epochs, val_acc, "b", label = "Validation acc")
plt.legend()
plt.title("Training and Validation acc")

plt.figure()

plt.plot(epochs, loss, "bo", label = "Training loss")
plt.plot(epochs, val_loss, "b", label = "Validation loss")
plt.legend()
plt.title("Training and Validation loss")

plt.show()

# %%
# 역방향 LSTM 모델링
# 순방향 LSTM 모델링

from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence

max_words = 10000
maxlen_for_padding = 500

(train_x, train_y), (test_x, test_y) = imdb.load_data(num_words=max_words)

train_x = [i[::-1] for i in train_x]
text_x = [i[::-1] for i in test_x]

train_x = sequence.pad_sequences(train_x, maxlen=maxlen_for_padding)
test_x = sequence.pad_sequences(test_x, maxlen=maxlen_for_padding)

model = Sequential()

# Embedding층의 input_lenth 매개변수를 지정하면, summary에 한 개 데이터에 대한 timesteps도 표시된다.
model.add(Embedding(max_words, 32, input_length = maxlen_for_padding))
model.add(LSTM(32))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer="rmsprop", loss = "binary_crossentropy", metrics=["acc"])

history = model.fit(train_x, train_y, batch_size = 128, epochs = 10, validation_split = 0.2)
# Out:
# Epoch 1/10
# 157/157 [==============================] - 38s 245ms/step - loss: 0.5300 - acc: 0.7410 - val_loss: 0.3254 - val_acc: 0.8744
# Epoch 2/10
# 157/157 [==============================] - 40s 256ms/step - loss: 0.3276 - acc: 0.8753 - val_loss: 0.3706 - val_acc: 0.8430
# Epoch 3/10
# 157/157 [==============================] - 39s 250ms/step - loss: 0.2608 - acc: 0.9036 - val_loss: 0.2903 - val_acc: 0.8836
# Epoch 4/10
# 157/157 [==============================] - 44s 277ms/step - loss: 0.2314 - acc: 0.9202 - val_loss: 0.3030 - val_acc: 0.8792
# Epoch 5/10
# 157/157 [==============================] - 39s 250ms/step - loss: 0.1989 - acc: 0.9296 - val_loss: 0.3787 - val_acc: 0.8700
# Epoch 6/10
# 157/157 [==============================] - 40s 253ms/step - loss: 0.1754 - acc: 0.9390 - val_loss: 0.3272 - val_acc: 0.8698
# Epoch 7/10
# 157/157 [==============================] - 39s 246ms/step - loss: 0.1601 - acc: 0.9445 - val_loss: 0.6396 - val_acc: 0.8258
# Epoch 8/10
# 157/157 [==============================] - 40s 253ms/step - loss: 0.1460 - acc: 0.9492 - val_loss: 0.3375 - val_acc: 0.8854
# Epoch 9/10
# 157/157 [==============================] - 40s 255ms/step - loss: 0.1366 - acc: 0.9542 - val_loss: 0.4575 - val_acc: 0.8750
# Epoch 10/10
# 157/157 [==============================] - 43s 274ms/step - loss: 0.1267 - acc: 0.9592 - val_loss: 0.3876 - val_acc: 0.8718

# %%
# 위 모델링에 대한 결과
# %matplotlib inline

acc = history.history["acc"]
loss = history.history["loss"]
val_acc = history.history["val_acc"]
val_loss = history.history["val_loss"]

epochs = list(range(1, len(acc) + 1))

plt.plot(epochs, acc, "bo", label = "Training acc")
plt.plot(epochs, val_acc, "b", label = "Validation acc")
plt.legend()
plt.title("Training and Validation acc")

plt.figure()

plt.plot(epochs, loss, "bo", label = "Training loss")
plt.plot(epochs, val_loss, "b", label = "Validation loss")
plt.legend()
plt.title("Training and Validation loss")

plt.show()
